# %%
from config import get_config
cfg = get_config()
cfg['batch_size'] = 64
cfg['preload'] = 29
cfg['num_epochs'] = 31

from train_wb import train_model

train_model(cfg)
# Out:
# Error in callback <bound method _WandbInit._resume_backend of <wandb.sdk.wandb_init._WandbInit object at 0x7fc8d807ea30>> (for pre_run_cell), with arguments args (<ExecutionInfo object at 7fc7c5a521c0, raw_cell="from config import get_config
# cfg = get_config()
# c.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224c4c5f41363030305f4475616c227d/home/ubuntu/DBI-7/pytorch-transformer/Local_Train.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D>,),kwargs {}:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: _resume_backend() takes 1 positional argument but 2 were given
# Using device: cuda
# Finishing last run (ID:8vi8tpx9) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# ...
